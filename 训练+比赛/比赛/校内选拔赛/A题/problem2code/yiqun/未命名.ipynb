# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
route=[[20,7,4,3,2,20],[20,8,1,20],[20,6,11,12,5,20],[20,14,15,16,18,20],[20,9,10,17,20],[20,13,19,20]]
col=['b','r','g','y','c','k']

# %%
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.savefig('route.png', dpi=300)

# %%
for i in range(len(route)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
route=[[20,6,11,20,13,12,20,8,20,14,19,20,2,20],[20,7,3,1,20,9,10,17,20,15,16,18,20,4,5,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.savefig('route.png', dpi=300)

# %%
#route=[[20,6,11,20,13,12,20,8,20,14,19,20,2,20],[20,7,3,1,20,9,10,17,20,15,16,18,20,4,5,20]]
route=[[20,6,11,20],[20,13,12,20],[20,8,20],[20,14,19,20]]
route = np.array(route)
plt.subplot(1,2,1)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('4吨车路线')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
route=[[20,7,3,1,20],[20,9,10,17,20],[20,15,16,18,20],[20,4,5,20]]
route=np.array(route)
plt.subplot(1,2,2)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('6吨车路线')
plt.savefig('46route.png', dpi=300)

# %%
#route=[[20,7,4,2,5,20,9,10,17,20,18,20],[20,6,11,12,20,13,19,14,20,8,3,20,15,16,20,1,20]]
route=[[20,7,4,2,5,20],[20,9,10,17,20],[20,18,20]]
route = np.array(route)
plt.subplot(1,2,1)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('6吨车一号路线')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
#route=[[20,7,4,2,5,20,9,10,17,20,18,20],[20,6,11,12,20,13,19,14,20,8,3,20,15,16,20,1,20]]
route=[[20,6,11,12,20],[20,13,19,14,20],[20,8,3,20],[20,15,16,20],[20,1,20]]
route=np.array(route)
plt.subplot(1,2,2)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('6吨车二号路线')
plt.savefig('66route.png', dpi=300)

# %%
route=[[20,3,1,20],[20,9,10,20],[20,2,20],[20,16,17,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('一号4吨车路线')
plt.savefig('route4_1.png', dpi=300)

# %%
route=[[20,13,19,20],[20,8,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('6吨车路线')
plt.savefig('route6.png', dpi=300)

# %%
route=[[20,14,20],[20,7,4,5,20],[20,15,18,20],[20,6,11,20],[20,12,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('二号4吨车路线')
plt.savefig('route4_2.png', dpi=300)

# %%
#route=[[20,6,11,20,4,2,20,15,18,20,13,12,20,16,20],[20,14,19,20,8,20,7,3,20,10,17,20,9,1,20,5,20]]
route=[[20,6,11,20],[20,4,2,20],[20,15,18,20],[20,13,12,20],[20,16,20]]
route = np.array(route)
plt.subplot(1,2,1)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('一号4吨车路线')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
##route=[[20,6,11,20,4,2,20,15,18,20,13,12,20,16,20],[20,14,19,20,8,20,7,3,20,10,17,20,9,1,20,5,20]]
route=[[20,14,19,20],[20,8,20],[20,7,3,20],[20,10,17,20],[20,9,1,20],[20,5,20]]
route=np.array(route)
plt.subplot(1,2,2)
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('二号4吨车路线')
plt.savefig('44route.png', dpi=300)

# %%
route=[[20,7,4,5,20],[20,3,1,20],[20,13,19,20],[20,9,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('一号4吨车路线')
plt.savefig('route4_1.png', dpi=300)

# %%
route=[[20,6,11,20],[20,15,18,20],[20,2,20],[20,16,20],[20,8,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('二号4吨车路线')
plt.savefig('route4_2.png', dpi=300)

# %%
route=[[20,14,20],[20,10,17,20],[20,12,20]]
x_coordinates=[3,1,5,4,0,3,7,9,10,14,2,6,11,15,19,22,21,27,15]
y_coordinates=[2,5,4,7,8,11,9,6,2,0,16,18,17,12,9,5,0,9,19]
z_coordinates=[2.5,2,1.5,1.2,0.85,1.3,1.2,3.3,1.4,1.8,2.5,0.8,1.5,0.9,1.4,2.2,1.8,1.4,1.6]
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
z_coordinates = np.array(z_coordinates)
z_coordinate = z_coordinates/(max(z_coordinates)-min(z_coordinates))
plt.grid(linestyle='-.', alpha=0.2)
plt.scatter(x_coordinates,y_coordinates, s=z_coordinates*50, c=z_coordinate, cmap=plt.cm.Reds)
plt.scatter(10, 10, marker='*', s = 300, c='r', alpha=0.8)
plt.xlabel('X/km')
plt.ylabel('Y/km')
plt.title('')
x_coordinates = x_coordinates.tolist()
y_coordinates = y_coordinates.tolist()
x_coordinates.append(10)
y_coordinates.append(10)
x_coordinates = np.array(x_coordinates)
y_coordinates = np.array(y_coordinates)
route = np.array(route)
for i in range(len(route)):
    for j in range(len(route[i])-1):
        plt.plot([x_coordinates[route[i][j]-1], x_coordinates[route[i][j+1]-1], x_coordinates[route[i][j+1]-1]], [y_coordinates[route[i][j]-1], y_coordinates[route[i][j]-1], y_coordinates[route[i][j+1]-1]],col[i])
plt.title('三号4吨车路线')
plt.savefig('route4_3.png', dpi=300)
